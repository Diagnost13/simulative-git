# %% [markdown]
# <a href="https://colab.research.google.com/github/Diagnost13/simulative-git/blob/master/%D0%90%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D1%81%D1%82%D1%8C_Itresume.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **2 кейс**
#
# **Выгрузка активности с ItResume**

# %% [markdown]
# **Важно**
#
# Перед началом решения выполните следующую ячейку, чтобы загрузить необходимый для работы файл.

# %%
# !wget https://gist.github.com/Vs8th/a7a7f00e6cdef1b3fe87e4d61ca56e5f/raw/codesubmit.csv
# Out:
# --2026-03-13 07:48:51--  https://gist.github.com/Vs8th/a7a7f00e6cdef1b3fe87e4d61ca56e5f/raw/codesubmit.csv
# Resolving gist.github.com (gist.github.com)... 140.82.112.4
# Connecting to gist.github.com (gist.github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/a7a7f00e6cdef1b3fe87e4d61ca56e5f/raw/codesubmit.csv [following]
# --2026-03-13 07:48:51--  https://gist.githubusercontent.com/Vs8th/a7a7f00e6cdef1b3fe87e4d61ca56e5f/raw/codesubmit.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 215378 (210K) [text/plain]
# Saving to: ‘codesubmit.csv’
#
# codesubmit.csv      100%[===================>] 210.33K  --.-KB/s    in 0.005s
#
# ...

# %% [markdown]
# Чтобы посмотреть как он выглядит выполните следующую ячейку.

# %%
import pandas as pd

df = pd.read_csv('codesubmit.csv', sep = ';')
df
# Out:
#                       created_at  user_id  problem_id  is_correct    type
# 0     2023-04-30 13:47:14.344471        7         870         1.0  submit
# 1     2023-04-30 13:46:15.949925        7         870         0.0  submit
# 2     2023-04-30 16:13:26.005286      173          21         1.0  submit
# 3     2023-04-30 16:13:06.739782      173          21         NaN     run
# 4     2023-04-30 15:52:00.195532      173          25         1.0  submit
# ...                          ...      ...         ...         ...     ...
# 4994  2023-04-30 21:52:00.269123    13493         435         NaN     run
# 4995  2023-04-30 21:51:01.094234    13493         435         1.0  submit
# 4996  2023-04-30 21:50:52.059690    13493         435         NaN     run
# 4997  2023-04-30 21:42:24.323689    13493        1086         NaN     run
# 4998  2023-04-30 21:36:13.783309    13493        1086         NaN     run
#
# [4999 rows x 5 columns]

# %% [markdown]
# ### **Решения**

# %% [markdown]
# #### **Задача 1**
#
# Ваша задача - выяснить сколько в среднем тратится времени на решение задачи.
#
# **Примечание**: для правильного подсчета - рассчитайте сначала среднее время решения по каждой задаче в отдельности, и только затем находите общее среднее время решения задач.
#
# Результат - число типа `float`, округлите до 2 знаков после запятой и запишите в переменную `res`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
import pandas as pd

# Загрузка данных
df = pd.read_csv('codesubmit.csv', sep=';', parse_dates=['created_at'])

# Приведение is_correct к числовому типу (пустые значения станут NaN)
df['is_correct'] = pd.to_numeric(df['is_correct'], errors='coerce')

# Сортировка по пользователю, задаче и времени
df = df.sort_values(['user_id', 'problem_id', 'created_at'])

# Группировка по паре (пользователь, задача)
groups = df.groupby(['user_id', 'problem_id'])

# Сбор результатов: (problem_id, время_решения_в_секундах)
records = []

for (user, problem), group in groups:
    # Успешные попытки
    successes = group[group['is_correct'] == 1]
    if successes.empty:
        continue                     # задача не решена
    first_success = successes['created_at'].min()
    first_event = group['created_at'].min()

    # Пропускаем «гениев» (решили с первой попытки)
    if first_event == first_success:
        continue

    delta = (first_success - first_event).total_seconds()
    records.append((problem, delta))

# Вычисление среднего времени по каждой задаче, затем общего среднего
if records:
    df_times = pd.DataFrame(records, columns=['problem_id', 'time'])
    avg_per_problem = df_times.groupby('problem_id')['time'].mean()
    overall_avg = avg_per_problem.mean()
    res = round(overall_avg, 2)
else:
    res = 0.0

# Результат сохраняется в переменной res

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
try:
    assert res == 611.86
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 2**
#
# Ваша задача - выяснить сколько часов в среднем проводит юзер в день на платформе. Перерывы в активности за день - не учитываем.
#
# Результат - число типа `float`, округлите до 2 знаков после запятой и запишите в переменную `res2`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
# Ваше решение здесь

# Предполагаем, что df уже загружен из предыдущей задачи
# Если нет, загрузим заново:
# df = pd.read_csv('codesubmit.csv', sep=';', parse_dates=['created_at'])

# Добавим столбец с датой (без времени)
df['date'] = df['created_at'].dt.date

# Группируем по пользователю и дате
grouped = df.groupby(['user_id', 'date'])['created_at']

# Вычисляем разницу между максимумом и минимумом в секундах, переводим в часы
daily_time = (grouped.max() - grouped.min()).dt.total_seconds() / 3600

# Убираем возможные нулевые значения? Но они учитываются в среднем.
# Вычисляем среднее по всем дням
res2 = round(daily_time.mean(), 2)

# Результат
res2
# Out:
# np.float64(1.7)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
try:
    assert res2 == 1.7
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 3**
#
# Теперь давайте посмотрим на активные сеансы. Выясните, сколько задач в среднем решается за один активный сеанс.
#
# **Активный сеанс** - период, когда между любой активностью пользователя разница менее или равна часу, не более
#
# **Важно**: в расчет берем не только успешные попытки решений (`is_correct=1`), а и неуспешные тоже (`is_correct=0`), и тип `run` в том числе.
#
# Результат - число типа `float`, округлите до 2 знаков после запятой и запишите в переменную `res3`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
# Ваше решение здесь

import pandas as pd

# Загрузка данных (если ещё не загружены)
# df = pd.read_csv('codesubmit.csv', sep=';', parse_dates=['created_at'])

# Сортировка по пользователю и времени
df = df.sort_values(['user_id', 'created_at']).copy()

# Разница во времени между последовательными действиями одного пользователя (в секундах)
df['time_diff'] = df.groupby('user_id')['created_at'].diff().dt.total_seconds()

# Новая сессия начинается, если разница > 3600 сек (1 час) или это первое действие
df['new_session'] = (df['time_diff'] > 3600) | (df['time_diff'].isna())

# Номер сессии для каждого пользователя
df['session_id'] = df.groupby('user_id')['new_session'].cumsum()

# Количество уникальных задач в каждой сессии
problems_per_session = df.groupby(['user_id', 'session_id'])['problem_id'].nunique()

# Среднее число задач за сессию
res3 = round(problems_per_session.mean(), 2)

# Результат
res3
# Out:
# np.float64(3.14)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
try:
    assert res3 == 3.14
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 4**
#
# И финальная - найдите самый "популярный" час дня на нашей платформе.
#
# Популярность определяем максимальным количеством уникальных пользователей, совершающих какую-либо активность в этот период
#
# Результат в числовом формате запишите в переменную `res4`.
#
# Например, самым популярным часом стал период с 22 до 23, тогда в переменной `res4` должно лежать **22**. Обозначающее начало этого периода.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
# Ваше решение здесь


# Извлечение часа из временной метки
df['hour'] = df['created_at'].dt.hour

# Подсчет уникальных пользователей по часам
hourly_users = df.groupby('hour')['user_id'].nunique()

# Поиск часа с максимальным количеством пользователей
# Если несколько, берем минимальный час (так как idxmax возвращает первый)
res4 = hourly_users.idxmax()

# Результат
res4
# Out:
# np.int32(16)

# %% [markdown]
# ✏️ ✏️ ✏️
#
# **Проверка**
#
# Чтобы проверить свое решение, запустите код в следующих ячейках

# %%
try:
    assert res4 == 16
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!
