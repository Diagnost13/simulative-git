# %% [markdown]
# <a href="https://colab.research.google.com/github/Diagnost13/simulative-git/blob/master/%D0%A2%D1%80%D0%B5%D0%BA_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **2 кейс**
#
# **Трек задач**

# %% [markdown]
# ### **Решения**

# %% [markdown]
# #### **Задача 1**
#
# Для начала определите классы `Task` и `Project`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class Task:
    def __init__(self, task_id, name, description, status, duration):
        self._task_id = task_id
        self._name = name
        self._description = description
        self._status = status
        self._duration = duration

    def get_task_id(self):
        return self._task_id

    def set_task_id(self, value):
        self._task_id = value

    def get_name(self):
        return self._name

    def set_name(self, value):
        self._name = value

    def get_description(self):
        return self._description

    def set_description(self, value):
        self._description = value

    def get_status(self):
        return self._status

    def set_status(self, value):
        self._status = value

    def get_duration(self):
        return self._duration

    def set_duration(self, value):
        self._duration = value

# %%
class Project:
    def __init__(self):
        self._tasks = []

    def add_task(self, task):
        self._tasks.append(task)

    def remove_task(self, task_id):
        for task in self._tasks:
            if task.get_task_id() == task_id:
                self._tasks.remove(task)
                return True
        return False

    def get_all_tasks(self):
        return self._tasks.copy()

    def __iter__(self):
        return iter(self._tasks)

# %%
#@title ✏️ Проверка: чтобы проверить свое решение запустите код в этой ячейке
task1 = Task(1, "Задача 1", "Описание", "Выполняется", 14)
task2 = Task(2, "Задача 2", "Описание", "Выполняется", 8)
task3 = Task(3, "Задача 3", "Описание", "Завершена", 3)
task4 = Task(4, "Задача 4", "Описание: срочно", "Выполняется", 7)

project = Project()
project.add_task(task1)
project.add_task(task2)
project.add_task(task3)
project.add_task(task4)

res = []
for task in project:
  name = task.get_name()
  description = task.get_description()
  status = task.get_status()
  res.append((name, description, status))

try:
    assert res == [('Задача 1', 'Описание', 'Выполняется'),
                   ('Задача 2', 'Описание', 'Выполняется'),
                   ('Задача 3', 'Описание', 'Завершена'),
                   ('Задача 4', 'Описание: срочно', 'Выполняется')]
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 2**
#
# Определите класс `Analysis`.

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class Analysis:
    @staticmethod
    def count_tasks(project):
        return len(project.get_all_tasks())

    @staticmethod
    def count_tasks_by_status(project, status):
        count = 0
        for task in project.get_all_tasks():
            if task.get_status() == status:
                count += 1
        return count

    @staticmethod
    def find_longest_task(project):
        tasks = project.get_all_tasks()
        if not tasks:
            return None
        longest = max(tasks, key=lambda task: task.get_duration())
        return longest

# %%
#@title ✏️ Проверка: чтобы проверить свое решение запустите код в этой ячейке
res2 = Analysis.count_tasks(project)
res3 = Analysis.count_tasks_by_status(project, "Выполняется")
res4 = Analysis.find_longest_task(project).get_name()

try:
    assert res2 == 4
    assert res3 == 3
    assert res4 == 'Задача 1'
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!

# %% [markdown]
# #### **Задача 3**
#
# Напишите `EnhancedAnalysis`

# %% [markdown]
# **Решение**
#
# Напишите свое решение ниже

# %%
class EnhancedAnalysis(Analysis):
    @staticmethod
    def find_tasks_with_keywords(project, keywords):
        """
        Возвращает список задач, в названии или описании которых встречается
        хотя бы одно из ключевых слов (с учётом регистра).
        """
        matching_tasks = []
        for task in project.get_all_tasks():
            name = task.get_name()
            description = task.get_description()
            for keyword in keywords:
                if keyword in name or keyword in description:
                    matching_tasks.append(task)
                    break  # избегаем дублирования одной задачи
        return matching_tasks

# %%
#@title ✏️ Проверка: чтобы проверить свое решение запустите код в этой ячейке
keywords = ["срочно"]
found_tasks = EnhancedAnalysis.find_tasks_with_keywords(project, keywords)
res5 = []
for task in found_tasks:
  res5.append(task.get_name())

try:
    assert res5 == ['Задача 4']
except AssertionError:
    print('Ответы не совпадают')
else:
    print('Поздравляем, Вы справились!')
# Out:
# Поздравляем, Вы справились!
